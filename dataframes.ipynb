# %%
import numpy as np
import pandas as pd
import seaborn as sns
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.age.unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
titanic.describe(include="all")
# Out:
#           survived      pclass   sex         age       sibsp       parch  \
# count   891.000000  891.000000   891  714.000000  891.000000  891.000000
# unique         NaN         NaN     2         NaN         NaN         NaN
# top            NaN         NaN  male         NaN         NaN         NaN
# freq           NaN         NaN   577         NaN         NaN         NaN
# mean      0.383838    2.308642   NaN   29.699118    0.523008    0.381594
# std       0.486592    0.836071   NaN   14.526497    1.102743    0.806057
# min       0.000000    1.000000   NaN    0.420000    0.000000    0.000000
# 25%       0.000000    2.000000   NaN   20.125000    0.000000    0.000000
# 50%       0.000000    3.000000   NaN   28.000000    0.000000    0.000000
# 75%       1.000000    3.000000   NaN   38.000000    1.000000    0.000000
# max       1.000000    3.000000   NaN   80.000000    8.000000    6.000000
#
#               fare embarked  class  who adult_male deck  embark_town alive  \
# count   891.000000      889    891  891        891  203          889   891
# unique         NaN        3      3    3          2    7            3     2
# top            NaN        S  Third  man       True    C  Southampton    no
# freq           NaN      644    491  537        537   59          644   549
# mean     32.204208      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# std      49.693429      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# min       0.000000      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# 25%       7.910400      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# 50%      14.454200      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# 75%      31.000000      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# max     512.329200      NaN    NaN  NaN        NaN  NaN          NaN   NaN
#
#        alone
# count    891
# unique     2
# top     True
# freq     537
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN

# %%
titanic.age.head(10)
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# 5     NaN
# 6    54.0
# 7     2.0
# 8    27.0
# 9    14.0
# Name: age, dtype: float64

# %%
titanic.fillna(value={"age": 0}).age.head(10)
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# 5     0.0
# 6    54.0
# 7     2.0
# 8    27.0
# 9    14.0
# Name: age, dtype: float64

# %%
titanic.fillna(method="pad").age.head(10)
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# 5    35.0
# 6    54.0
# 7     2.0
# 8    27.0
# 9    14.0
# Name: age, dtype: float64

# %%
titanic.dropna().head(10)
# Out:
#     survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 1          1       1  female  38.0      1      0   71.2833        C   First
# 3          1       1  female  35.0      1      0   53.1000        S   First
# 6          0       1    male  54.0      0      0   51.8625        S   First
# 10         1       3  female   4.0      1      1   16.7000        S   Third
# 11         1       1  female  58.0      0      0   26.5500        S   First
# 21         1       2    male  34.0      0      0   13.0000        S  Second
# 23         1       1    male  28.0      0      0   35.5000        S   First
# 27         0       1    male  19.0      3      2  263.0000        S   First
# 52         1       1  female  49.0      1      0   76.7292        C   First
# 54         0       1    male  65.0      0      1   61.9792        C   First
#
#       who  adult_male deck  embark_town alive  alone
# 1   woman       False    C    Cherbourg   yes  False
# 3   woman       False    C  Southampton   yes  False
# 6     man        True    E  Southampton    no   True
# 10  child       False    G  Southampton   yes  False
# 11  woman       False    C  Southampton   yes   True
# 21    man        True    D  Southampton   yes   True
# 23    man        True    A  Southampton   yes   True
# 27    man        True    C  Southampton    no  False
# 52  woman       False    D    Cherbourg   yes  False
# 54    man        True    B    Cherbourg    no  False

# %%
titanic.dropna(axis="columns").head()
# Out:
#    survived  pclass     sex  sibsp  parch     fare  class    who  adult_male  \
# 0         0       3    male      1      0   7.2500  Third    man        True
# 1         1       1  female      1      0  71.2833  First  woman       False
# 2         1       3  female      0      0   7.9250  Third  woman       False
# 3         1       1  female      1      0  53.1000  First  woman       False
# 4         0       3    male      0      0   8.0500  Third    man        True
#
#   alive  alone
# 0    no  False
# 1   yes  False
# 2   yes   True
# 3   yes  False
# 4    no   True

# %%
titanic.rename(columns={"sex":"sexe"})
# Out:
#      survived  pclass    sexe   age  sibsp  parch      fare embarked   class  \
# 0           0       3    male  22.0      1      0    7.2500        S   Third
# 1           1       1  female  38.0      1      0   71.2833        C   First
# 2           1       3  female  26.0      0      0    7.9250        S   Third
# 3           1       1  female  35.0      1      0   53.1000        S   First
# 4           0       3    male  35.0      0      0    8.0500        S   Third
# 5           0       3    male   NaN      0      0    8.4583        Q   Third
# 6           0       1    male  54.0      0      0   51.8625        S   First
# 7           0       3    male   2.0      3      1   21.0750        S   Third
# 8           1       3  female  27.0      0      2   11.1333        S   Third
# 9           1       2  female  14.0      1      0   30.0708        C  Second
# 10          1       3  female   4.0      1      1   16.7000        S   Third
# 11          1       1  female  58.0      0      0   26.5500        S   First
# 12          0       3    male  20.0      0      0    8.0500        S   Third
# 13          0       3    male  39.0      1      5   31.2750        S   Third
# 14          0       3  female  14.0      0      0    7.8542        S   Third
# 15          1       2  female  55.0      0      0   16.0000        S  Second
# 16          0       3    male   2.0      4      1   29.1250        Q   Third
# 17          1       2    male   NaN      0      0   13.0000        S  Second
# 18          0       3  female  31.0      1      0   18.0000        S   Third
# 19          1       3  female   NaN      0      0    7.2250        C   Third
# 20          0       2    male  35.0      0      0   26.0000        S  Second
# 21          1       2    male  34.0      0      0   13.0000        S  Second
# 22          1       3  female  15.0      0      0    8.0292        Q   Third
# 23          1       1    male  28.0      0      0   35.5000        S   First
# 24          0       3  female   8.0      3      1   21.0750        S   Third
# 25          1       3  female  38.0      1      5   31.3875        S   Third
# 26          0       3    male   NaN      0      0    7.2250        C   Third
# 27          0       1    male  19.0      3      2  263.0000        S   First
# 28          1       3  female   NaN      0      0    7.8792        Q   Third
# 29          0       3    male   NaN      0      0    7.8958        S   Third
# ..        ...     ...     ...   ...    ...    ...       ...      ...     ...
# 861         0       2    male  21.0      1      0   11.5000        S  Second
# 862         1       1  female  48.0      0      0   25.9292        S   First
# 863         0       3  female   NaN      8      2   69.5500        S   Third
# 864         0       2    male  24.0      0      0   13.0000        S  Second
# 865         1       2  female  42.0      0      0   13.0000        S  Second
# 866         1       2  female  27.0      1      0   13.8583        C  Second
# 867         0       1    male  31.0      0      0   50.4958        S   First
# 868         0       3    male   NaN      0      0    9.5000        S   Third
# 869         1       3    male   4.0      1      1   11.1333        S   Third
# 870         0       3    male  26.0      0      0    7.8958        S   Third
# 871         1       1  female  47.0      1      1   52.5542        S   First
# 872         0       1    male  33.0      0      0    5.0000        S   First
# 873         0       3    male  47.0      0      0    9.0000        S   Third
# 874         1       2  female  28.0      1      0   24.0000        C  Second
# 875         1       3  female  15.0      0      0    7.2250        C   Third
# 876         0       3    male  20.0      0      0    9.8458        S   Third
# 877         0       3    male  19.0      0      0    7.8958        S   Third
# 878         0       3    male   NaN      0      0    7.8958        S   Third
# 879         1       1  female  56.0      0      1   83.1583        C   First
# 880         1       2  female  25.0      0      1   26.0000        S  Second
# 881         0       3    male  33.0      0      0    7.8958        S   Third
# 882         0       3  female  22.0      0      0   10.5167        S   Third
# 883         0       2    male  28.0      0      0   10.5000        S  Second
# 884         0       3    male  25.0      0      0    7.0500        S   Third
# 885         0       3  female  39.0      0      5   29.1250        Q   Third
# 886         0       2    male  27.0      0      0   13.0000        S  Second
# 887         1       1  female  19.0      0      0   30.0000        S   First
# 888         0       3  female   NaN      1      2   23.4500        S   Third
# 889         1       1    male  26.0      0      0   30.0000        C   First
# 890         0       3    male  32.0      0      0    7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# 5      man        True  NaN   Queenstown    no   True
# 6      man        True    E  Southampton    no   True
# 7    child       False  NaN  Southampton    no  False
# 8    woman       False  NaN  Southampton   yes  False
# 9    child       False  NaN    Cherbourg   yes  False
# 10   child       False    G  Southampton   yes  False
# 11   woman       False    C  Southampton   yes   True
# 12     man        True  NaN  Southampton    no   True
# 13     man        True  NaN  Southampton    no  False
# 14   child       False  NaN  Southampton    no   True
# 15   woman       False  NaN  Southampton   yes   True
# 16   child       False  NaN   Queenstown    no  False
# 17     man        True  NaN  Southampton   yes   True
# 18   woman       False  NaN  Southampton    no  False
# 19   woman       False  NaN    Cherbourg   yes   True
# 20     man        True  NaN  Southampton    no   True
# 21     man        True    D  Southampton   yes   True
# 22   child       False  NaN   Queenstown   yes   True
# 23     man        True    A  Southampton   yes   True
# 24   child       False  NaN  Southampton    no  False
# 25   woman       False  NaN  Southampton   yes  False
# 26     man        True  NaN    Cherbourg    no   True
# 27     man        True    C  Southampton    no  False
# 28   woman       False  NaN   Queenstown   yes   True
# 29     man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 861    man        True  NaN  Southampton    no  False
# 862  woman       False    D  Southampton   yes   True
# 863  woman       False  NaN  Southampton    no  False
# 864    man        True  NaN  Southampton    no   True
# 865  woman       False  NaN  Southampton   yes   True
# 866  woman       False  NaN    Cherbourg   yes  False
# 867    man        True    A  Southampton    no   True
# 868    man        True  NaN  Southampton    no   True
# 869  child       False  NaN  Southampton   yes  False
# 870    man        True  NaN  Southampton    no   True
# 871  woman       False    D  Southampton   yes  False
# 872    man        True    B  Southampton    no   True
# 873    man        True  NaN  Southampton    no   True
# 874  woman       False  NaN    Cherbourg   yes  False
# 875  child       False  NaN    Cherbourg   yes   True
# 876    man        True  NaN  Southampton    no   True
# 877    man        True  NaN  Southampton    no   True
# 878    man        True  NaN  Southampton    no   True
# 879  woman       False    C    Cherbourg   yes  False
# 880  woman       False  NaN  Southampton   yes  False
# 881    man        True  NaN  Southampton    no   True
# 882  woman       False  NaN  Southampton    no   True
# 883    man        True  NaN  Southampton    no   True
# 884    man        True  NaN  Southampton    no   True
# 885  woman       False  NaN   Queenstown    no  False
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
f = lambda x: x+1
titanic.rename(index=f)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 1           0       3    male  22.0      1      0    7.2500        S   Third
# 2           1       1  female  38.0      1      0   71.2833        C   First
# 3           1       3  female  26.0      0      0    7.9250        S   Third
# 4           1       1  female  35.0      1      0   53.1000        S   First
# 5           0       3    male  35.0      0      0    8.0500        S   Third
# 6           0       3    male   NaN      0      0    8.4583        Q   Third
# 7           0       1    male  54.0      0      0   51.8625        S   First
# 8           0       3    male   2.0      3      1   21.0750        S   Third
# 9           1       3  female  27.0      0      2   11.1333        S   Third
# 10          1       2  female  14.0      1      0   30.0708        C  Second
# 11          1       3  female   4.0      1      1   16.7000        S   Third
# 12          1       1  female  58.0      0      0   26.5500        S   First
# 13          0       3    male  20.0      0      0    8.0500        S   Third
# 14          0       3    male  39.0      1      5   31.2750        S   Third
# 15          0       3  female  14.0      0      0    7.8542        S   Third
# 16          1       2  female  55.0      0      0   16.0000        S  Second
# 17          0       3    male   2.0      4      1   29.1250        Q   Third
# 18          1       2    male   NaN      0      0   13.0000        S  Second
# 19          0       3  female  31.0      1      0   18.0000        S   Third
# 20          1       3  female   NaN      0      0    7.2250        C   Third
# 21          0       2    male  35.0      0      0   26.0000        S  Second
# 22          1       2    male  34.0      0      0   13.0000        S  Second
# 23          1       3  female  15.0      0      0    8.0292        Q   Third
# 24          1       1    male  28.0      0      0   35.5000        S   First
# 25          0       3  female   8.0      3      1   21.0750        S   Third
# 26          1       3  female  38.0      1      5   31.3875        S   Third
# 27          0       3    male   NaN      0      0    7.2250        C   Third
# 28          0       1    male  19.0      3      2  263.0000        S   First
# 29          1       3  female   NaN      0      0    7.8792        Q   Third
# 30          0       3    male   NaN      0      0    7.8958        S   Third
# ..        ...     ...     ...   ...    ...    ...       ...      ...     ...
# 862         0       2    male  21.0      1      0   11.5000        S  Second
# 863         1       1  female  48.0      0      0   25.9292        S   First
# 864         0       3  female   NaN      8      2   69.5500        S   Third
# 865         0       2    male  24.0      0      0   13.0000        S  Second
# 866         1       2  female  42.0      0      0   13.0000        S  Second
# 867         1       2  female  27.0      1      0   13.8583        C  Second
# 868         0       1    male  31.0      0      0   50.4958        S   First
# 869         0       3    male   NaN      0      0    9.5000        S   Third
# 870         1       3    male   4.0      1      1   11.1333        S   Third
# 871         0       3    male  26.0      0      0    7.8958        S   Third
# 872         1       1  female  47.0      1      1   52.5542        S   First
# 873         0       1    male  33.0      0      0    5.0000        S   First
# 874         0       3    male  47.0      0      0    9.0000        S   Third
# 875         1       2  female  28.0      1      0   24.0000        C  Second
# 876         1       3  female  15.0      0      0    7.2250        C   Third
# 877         0       3    male  20.0      0      0    9.8458        S   Third
# 878         0       3    male  19.0      0      0    7.8958        S   Third
# 879         0       3    male   NaN      0      0    7.8958        S   Third
# 880         1       1  female  56.0      0      1   83.1583        C   First
# 881         1       2  female  25.0      0      1   26.0000        S  Second
# 882         0       3    male  33.0      0      0    7.8958        S   Third
# 883         0       3  female  22.0      0      0   10.5167        S   Third
# 884         0       2    male  28.0      0      0   10.5000        S  Second
# 885         0       3    male  25.0      0      0    7.0500        S   Third
# 886         0       3  female  39.0      0      5   29.1250        Q   Third
# 887         0       2    male  27.0      0      0   13.0000        S  Second
# 888         1       1  female  19.0      0      0   30.0000        S   First
# 889         0       3  female   NaN      1      2   23.4500        S   Third
# 890         1       1    male  26.0      0      0   30.0000        C   First
# 891         0       3    male  32.0      0      0    7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 1      man        True  NaN  Southampton    no  False
# 2    woman       False    C    Cherbourg   yes  False
# 3    woman       False  NaN  Southampton   yes   True
# 4    woman       False    C  Southampton   yes  False
# 5      man        True  NaN  Southampton    no   True
# 6      man        True  NaN   Queenstown    no   True
# 7      man        True    E  Southampton    no   True
# 8    child       False  NaN  Southampton    no  False
# 9    woman       False  NaN  Southampton   yes  False
# 10   child       False  NaN    Cherbourg   yes  False
# 11   child       False    G  Southampton   yes  False
# 12   woman       False    C  Southampton   yes   True
# 13     man        True  NaN  Southampton    no   True
# 14     man        True  NaN  Southampton    no  False
# 15   child       False  NaN  Southampton    no   True
# 16   woman       False  NaN  Southampton   yes   True
# 17   child       False  NaN   Queenstown    no  False
# 18     man        True  NaN  Southampton   yes   True
# 19   woman       False  NaN  Southampton    no  False
# 20   woman       False  NaN    Cherbourg   yes   True
# 21     man        True  NaN  Southampton    no   True
# 22     man        True    D  Southampton   yes   True
# 23   child       False  NaN   Queenstown   yes   True
# 24     man        True    A  Southampton   yes   True
# 25   child       False  NaN  Southampton    no  False
# 26   woman       False  NaN  Southampton   yes  False
# 27     man        True  NaN    Cherbourg    no   True
# 28     man        True    C  Southampton    no  False
# 29   woman       False  NaN   Queenstown   yes   True
# 30     man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 862    man        True  NaN  Southampton    no  False
# 863  woman       False    D  Southampton   yes   True
# 864  woman       False  NaN  Southampton    no  False
# 865    man        True  NaN  Southampton    no   True
# 866  woman       False  NaN  Southampton   yes   True
# 867  woman       False  NaN    Cherbourg   yes  False
# 868    man        True    A  Southampton    no   True
# 869    man        True  NaN  Southampton    no   True
# 870  child       False  NaN  Southampton   yes  False
# 871    man        True  NaN  Southampton    no   True
# 872  woman       False    D  Southampton   yes  False
# 873    man        True    B  Southampton    no   True
# 874    man        True  NaN  Southampton    no   True
# 875  woman       False  NaN    Cherbourg   yes  False
# 876  child       False  NaN    Cherbourg   yes   True
# 877    man        True  NaN  Southampton    no   True
# 878    man        True  NaN  Southampton    no   True
# 879    man        True  NaN  Southampton    no   True
# 880  woman       False    C    Cherbourg   yes  False
# 881  woman       False  NaN  Southampton   yes  False
# 882    man        True  NaN  Southampton    no   True
# 883  woman       False  NaN  Southampton    no   True
# 884    man        True  NaN  Southampton    no   True
# 885    man        True  NaN  Southampton    no   True
# 886  woman       False  NaN   Queenstown    no  False
# 887    man        True  NaN  Southampton    no   True
# 888  woman       False    B  Southampton   yes   True
# 889  woman       False  NaN  Southampton    no  False
# 890    man        True    C    Cherbourg   yes   True
# 891    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
titanic.drop(0)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 1           1       1  female  38.0      1      0   71.2833        C   First
# 2           1       3  female  26.0      0      0    7.9250        S   Third
# 3           1       1  female  35.0      1      0   53.1000        S   First
# 4           0       3    male  35.0      0      0    8.0500        S   Third
# 5           0       3    male   NaN      0      0    8.4583        Q   Third
# 6           0       1    male  54.0      0      0   51.8625        S   First
# 7           0       3    male   2.0      3      1   21.0750        S   Third
# 8           1       3  female  27.0      0      2   11.1333        S   Third
# 9           1       2  female  14.0      1      0   30.0708        C  Second
# 10          1       3  female   4.0      1      1   16.7000        S   Third
# 11          1       1  female  58.0      0      0   26.5500        S   First
# 12          0       3    male  20.0      0      0    8.0500        S   Third
# 13          0       3    male  39.0      1      5   31.2750        S   Third
# 14          0       3  female  14.0      0      0    7.8542        S   Third
# 15          1       2  female  55.0      0      0   16.0000        S  Second
# 16          0       3    male   2.0      4      1   29.1250        Q   Third
# 17          1       2    male   NaN      0      0   13.0000        S  Second
# 18          0       3  female  31.0      1      0   18.0000        S   Third
# 19          1       3  female   NaN      0      0    7.2250        C   Third
# 20          0       2    male  35.0      0      0   26.0000        S  Second
# 21          1       2    male  34.0      0      0   13.0000        S  Second
# 22          1       3  female  15.0      0      0    8.0292        Q   Third
# 23          1       1    male  28.0      0      0   35.5000        S   First
# 24          0       3  female   8.0      3      1   21.0750        S   Third
# 25          1       3  female  38.0      1      5   31.3875        S   Third
# 26          0       3    male   NaN      0      0    7.2250        C   Third
# 27          0       1    male  19.0      3      2  263.0000        S   First
# 28          1       3  female   NaN      0      0    7.8792        Q   Third
# 29          0       3    male   NaN      0      0    7.8958        S   Third
# 30          0       1    male  40.0      0      0   27.7208        C   First
# ..        ...     ...     ...   ...    ...    ...       ...      ...     ...
# 861         0       2    male  21.0      1      0   11.5000        S  Second
# 862         1       1  female  48.0      0      0   25.9292        S   First
# 863         0       3  female   NaN      8      2   69.5500        S   Third
# 864         0       2    male  24.0      0      0   13.0000        S  Second
# 865         1       2  female  42.0      0      0   13.0000        S  Second
# 866         1       2  female  27.0      1      0   13.8583        C  Second
# 867         0       1    male  31.0      0      0   50.4958        S   First
# 868         0       3    male   NaN      0      0    9.5000        S   Third
# 869         1       3    male   4.0      1      1   11.1333        S   Third
# 870         0       3    male  26.0      0      0    7.8958        S   Third
# 871         1       1  female  47.0      1      1   52.5542        S   First
# 872         0       1    male  33.0      0      0    5.0000        S   First
# 873         0       3    male  47.0      0      0    9.0000        S   Third
# 874         1       2  female  28.0      1      0   24.0000        C  Second
# 875         1       3  female  15.0      0      0    7.2250        C   Third
# 876         0       3    male  20.0      0      0    9.8458        S   Third
# 877         0       3    male  19.0      0      0    7.8958        S   Third
# 878         0       3    male   NaN      0      0    7.8958        S   Third
# 879         1       1  female  56.0      0      1   83.1583        C   First
# 880         1       2  female  25.0      0      1   26.0000        S  Second
# 881         0       3    male  33.0      0      0    7.8958        S   Third
# 882         0       3  female  22.0      0      0   10.5167        S   Third
# 883         0       2    male  28.0      0      0   10.5000        S  Second
# 884         0       3    male  25.0      0      0    7.0500        S   Third
# 885         0       3  female  39.0      0      5   29.1250        Q   Third
# 886         0       2    male  27.0      0      0   13.0000        S  Second
# 887         1       1  female  19.0      0      0   30.0000        S   First
# 888         0       3  female   NaN      1      2   23.4500        S   Third
# 889         1       1    male  26.0      0      0   30.0000        C   First
# 890         0       3    male  32.0      0      0    7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# 5      man        True  NaN   Queenstown    no   True
# 6      man        True    E  Southampton    no   True
# 7    child       False  NaN  Southampton    no  False
# 8    woman       False  NaN  Southampton   yes  False
# 9    child       False  NaN    Cherbourg   yes  False
# 10   child       False    G  Southampton   yes  False
# 11   woman       False    C  Southampton   yes   True
# 12     man        True  NaN  Southampton    no   True
# 13     man        True  NaN  Southampton    no  False
# 14   child       False  NaN  Southampton    no   True
# 15   woman       False  NaN  Southampton   yes   True
# 16   child       False  NaN   Queenstown    no  False
# 17     man        True  NaN  Southampton   yes   True
# 18   woman       False  NaN  Southampton    no  False
# 19   woman       False  NaN    Cherbourg   yes   True
# 20     man        True  NaN  Southampton    no   True
# 21     man        True    D  Southampton   yes   True
# 22   child       False  NaN   Queenstown   yes   True
# 23     man        True    A  Southampton   yes   True
# 24   child       False  NaN  Southampton    no  False
# 25   woman       False  NaN  Southampton   yes  False
# 26     man        True  NaN    Cherbourg    no   True
# 27     man        True    C  Southampton    no  False
# 28   woman       False  NaN   Queenstown   yes   True
# 29     man        True  NaN  Southampton    no   True
# 30     man        True  NaN    Cherbourg    no   True
# ..     ...         ...  ...          ...   ...    ...
# 861    man        True  NaN  Southampton    no  False
# 862  woman       False    D  Southampton   yes   True
# 863  woman       False  NaN  Southampton    no  False
# 864    man        True  NaN  Southampton    no   True
# 865  woman       False  NaN  Southampton   yes   True
# 866  woman       False  NaN    Cherbourg   yes  False
# 867    man        True    A  Southampton    no   True
# 868    man        True  NaN  Southampton    no   True
# 869  child       False  NaN  Southampton   yes  False
# 870    man        True  NaN  Southampton    no   True
# 871  woman       False    D  Southampton   yes  False
# 872    man        True    B  Southampton    no   True
# 873    man        True  NaN  Southampton    no   True
# 874  woman       False  NaN    Cherbourg   yes  False
# 875  child       False  NaN    Cherbourg   yes   True
# 876    man        True  NaN  Southampton    no   True
# 877    man        True  NaN  Southampton    no   True
# 878    man        True  NaN  Southampton    no   True
# 879  woman       False    C    Cherbourg   yes  False
# 880  woman       False  NaN  Southampton   yes  False
# 881    man        True  NaN  Southampton    no   True
# 882  woman       False  NaN  Southampton    no   True
# 883    man        True  NaN  Southampton    no   True
# 884    man        True  NaN  Southampton    no   True
# 885  woman       False  NaN   Queenstown    no  False
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [890 rows x 15 columns]

# %%
titanic.drop(columns=["age"])
# Out:
#      survived  pclass     sex  sibsp  parch      fare embarked   class    who  \
# 0           0       3    male      1      0    7.2500        S   Third    man
# 1           1       1  female      1      0   71.2833        C   First  woman
# 2           1       3  female      0      0    7.9250        S   Third  woman
# 3           1       1  female      1      0   53.1000        S   First  woman
# 4           0       3    male      0      0    8.0500        S   Third    man
# 5           0       3    male      0      0    8.4583        Q   Third    man
# 6           0       1    male      0      0   51.8625        S   First    man
# 7           0       3    male      3      1   21.0750        S   Third  child
# 8           1       3  female      0      2   11.1333        S   Third  woman
# 9           1       2  female      1      0   30.0708        C  Second  child
# 10          1       3  female      1      1   16.7000        S   Third  child
# 11          1       1  female      0      0   26.5500        S   First  woman
# 12          0       3    male      0      0    8.0500        S   Third    man
# 13          0       3    male      1      5   31.2750        S   Third    man
# 14          0       3  female      0      0    7.8542        S   Third  child
# 15          1       2  female      0      0   16.0000        S  Second  woman
# 16          0       3    male      4      1   29.1250        Q   Third  child
# 17          1       2    male      0      0   13.0000        S  Second    man
# 18          0       3  female      1      0   18.0000        S   Third  woman
# 19          1       3  female      0      0    7.2250        C   Third  woman
# 20          0       2    male      0      0   26.0000        S  Second    man
# 21          1       2    male      0      0   13.0000        S  Second    man
# 22          1       3  female      0      0    8.0292        Q   Third  child
# 23          1       1    male      0      0   35.5000        S   First    man
# 24          0       3  female      3      1   21.0750        S   Third  child
# 25          1       3  female      1      5   31.3875        S   Third  woman
# 26          0       3    male      0      0    7.2250        C   Third    man
# 27          0       1    male      3      2  263.0000        S   First    man
# 28          1       3  female      0      0    7.8792        Q   Third  woman
# 29          0       3    male      0      0    7.8958        S   Third    man
# ..        ...     ...     ...    ...    ...       ...      ...     ...    ...
# 861         0       2    male      1      0   11.5000        S  Second    man
# 862         1       1  female      0      0   25.9292        S   First  woman
# 863         0       3  female      8      2   69.5500        S   Third  woman
# 864         0       2    male      0      0   13.0000        S  Second    man
# 865         1       2  female      0      0   13.0000        S  Second  woman
# 866         1       2  female      1      0   13.8583        C  Second  woman
# 867         0       1    male      0      0   50.4958        S   First    man
# 868         0       3    male      0      0    9.5000        S   Third    man
# 869         1       3    male      1      1   11.1333        S   Third  child
# 870         0       3    male      0      0    7.8958        S   Third    man
# 871         1       1  female      1      1   52.5542        S   First  woman
# 872         0       1    male      0      0    5.0000        S   First    man
# 873         0       3    male      0      0    9.0000        S   Third    man
# 874         1       2  female      1      0   24.0000        C  Second  woman
# 875         1       3  female      0      0    7.2250        C   Third  child
# 876         0       3    male      0      0    9.8458        S   Third    man
# 877         0       3    male      0      0    7.8958        S   Third    man
# 878         0       3    male      0      0    7.8958        S   Third    man
# 879         1       1  female      0      1   83.1583        C   First  woman
# 880         1       2  female      0      1   26.0000        S  Second  woman
# 881         0       3    male      0      0    7.8958        S   Third    man
# 882         0       3  female      0      0   10.5167        S   Third  woman
# 883         0       2    male      0      0   10.5000        S  Second    man
# 884         0       3    male      0      0    7.0500        S   Third    man
# 885         0       3  female      0      5   29.1250        Q   Third  woman
# 886         0       2    male      0      0   13.0000        S  Second    man
# 887         1       1  female      0      0   30.0000        S   First  woman
# 888         0       3  female      1      2   23.4500        S   Third  woman
# 889         1       1    male      0      0   30.0000        C   First    man
# 890         0       3    male      0      0    7.7500        Q   Third    man
#
#      adult_male deck  embark_town alive  alone
# 0          True  NaN  Southampton    no  False
# 1         False    C    Cherbourg   yes  False
# 2         False  NaN  Southampton   yes   True
# 3         False    C  Southampton   yes  False
# 4          True  NaN  Southampton    no   True
# 5          True  NaN   Queenstown    no   True
# 6          True    E  Southampton    no   True
# 7         False  NaN  Southampton    no  False
# 8         False  NaN  Southampton   yes  False
# 9         False  NaN    Cherbourg   yes  False
# 10        False    G  Southampton   yes  False
# 11        False    C  Southampton   yes   True
# 12         True  NaN  Southampton    no   True
# 13         True  NaN  Southampton    no  False
# 14        False  NaN  Southampton    no   True
# 15        False  NaN  Southampton   yes   True
# 16        False  NaN   Queenstown    no  False
# 17         True  NaN  Southampton   yes   True
# 18        False  NaN  Southampton    no  False
# 19        False  NaN    Cherbourg   yes   True
# 20         True  NaN  Southampton    no   True
# 21         True    D  Southampton   yes   True
# 22        False  NaN   Queenstown   yes   True
# 23         True    A  Southampton   yes   True
# 24        False  NaN  Southampton    no  False
# 25        False  NaN  Southampton   yes  False
# 26         True  NaN    Cherbourg    no   True
# 27         True    C  Southampton    no  False
# 28        False  NaN   Queenstown   yes   True
# 29         True  NaN  Southampton    no   True
# ..          ...  ...          ...   ...    ...
# 861        True  NaN  Southampton    no  False
# 862       False    D  Southampton   yes   True
# 863       False  NaN  Southampton    no  False
# 864        True  NaN  Southampton    no   True
# 865       False  NaN  Southampton   yes   True
# 866       False  NaN    Cherbourg   yes  False
# 867        True    A  Southampton    no   True
# 868        True  NaN  Southampton    no   True
# 869       False  NaN  Southampton   yes  False
# 870        True  NaN  Southampton    no   True
# 871       False    D  Southampton   yes  False
# 872        True    B  Southampton    no   True
# 873        True  NaN  Southampton    no   True
# 874       False  NaN    Cherbourg   yes  False
# 875       False  NaN    Cherbourg   yes   True
# 876        True  NaN  Southampton    no   True
# 877        True  NaN  Southampton    no   True
# 878        True  NaN  Southampton    no   True
# 879       False    C    Cherbourg   yes  False
# 880       False  NaN  Southampton   yes  False
# 881        True  NaN  Southampton    no   True
# 882       False  NaN  Southampton    no   True
# 883        True  NaN  Southampton    no   True
# 884        True  NaN  Southampton    no   True
# 885       False  NaN   Queenstown    no  False
# 886        True  NaN  Southampton    no   True
# 887       False    B  Southampton   yes   True
# 888       False  NaN  Southampton    no  False
# 889        True    C    Cherbourg   yes   True
# 890        True  NaN   Queenstown    no   True
#
# [891 rows x 14 columns]

# %%
titanic.pivot_table('survived', index='sex', columns='class')
# Out:
# class      First    Second     Third
# sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %%
titanic.pivot_table('survived', index='sex', columns='class', aggfunc="sum")
# Out:
# class   First  Second  Third
# sex
# female     91      70     72
# male       45      17     47

# %%
titanic.dropna(inplace=True)
age = pd.cut(titanic['age'], [0, 18, 80])
titanic.pivot_table('survived', ['sex', age], 'class')
# Out:
# class               First    Second     Third
# sex    age
# female (0, 18]   0.909091  1.000000  0.500000
#        (18, 80]  0.968254  0.875000  0.666667
# male   (0, 18]   0.800000  1.000000  1.000000
#        (18, 80]  0.397436  0.333333  0.250000
